# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('datasets/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.dropna()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df['sex'] = LabelEncoder().fit_transform(df['sex'])
df['smoker'] = LabelEncoder().fit_transform(df['smoker'])
df['region'] = LabelEncoder().fit_transform(df['region'])
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      1.515695  13270.422265
# std       1.104885  12110.011237
# min       0.000000   1121.873900
# 25%       1.000000   4740.287150
# 50%       2.000000   9382.033000
# 75%       2.000000  16639.912515
# max       3.000000  63770.428010

# %%
df["smoker"].value_counts()[1]
# Out:
# 274

# %%
df["charges"] = StandardScaler().fit_transform(df["charges"].values.reshape(-1,1))
df["bmi"] = StandardScaler().fit_transform(df["bmi"].values.reshape(-1,1))
df["age"] = StandardScaler().fit_transform(df["age"].values.reshape(-1,1))
df.head()
# Out:
#         age  sex       bmi  children  smoker  region   charges
# 0 -1.438764    0 -0.453320         0       1       3  0.298584
# 1 -1.509965    1  0.509621         1       0       2 -0.953689
# 2 -0.797954    1  0.383307         3       0       2 -0.728675
# 3 -0.441948    1 -1.305531         0       0       1  0.719843
# 4 -0.513149    1 -0.292556         0       0       1 -0.776802

# %%
sns.pairplot(df.iloc[:,0:-1])

# %%
corr = df.iloc[:,0:-1].corr()
plt.figure(figsize=(8,8))
sns.heatmap(corr,cmap="coolwarm",annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,5))
ax=sns.boxplot(data=df.iloc[:,0:-1])

# %%
#Define variables for classifcation
y = df["charges"].values
X = df.iloc[:,0:-1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 0)
X_validate, X_test, y_validate, y_test = train_test_split(X_test,y_test,test_size=0.5,random_state=0)

# %%
num_trees = range(1,100)
scores_forest = []
results = 0
best_score_forest = 0

for nt in num_trees:
    
    model_forest = RandomForestRegressor(criterion='mse',max_leaf_nodes=100,n_estimators=nt)
    model_forest.fit(X_train,y_train.ravel())
    results = model_forest.score(X_test,y_test)
    scores_forest.append(round(results,2))
    
    if results > best_score_forest:
        best_score_forest = results
        best_nt = nt
        best_model_forest = model_forest
        
print("R2:",scores_forest)
print("Optimal number of trees:",best_nt)
# Out:
# R2: [0.63, 0.76, 0.78, 0.8, 0.79, 0.79, 0.84, 0.82, 0.77, 0.81, 0.8, 0.82, 0.82, 0.81, 0.81, 0.81, 0.82, 0.82, 0.81, 0.83, 0.79, 0.82, 0.82, 0.81, 0.81, 0.81, 0.81, 0.82, 0.83, 0.82, 0.82, 0.81, 0.82, 0.82, 0.81, 0.81, 0.83, 0.82, 0.82, 0.82, 0.82, 0.83, 0.81, 0.82, 0.83, 0.82, 0.83, 0.82, 0.82, 0.83, 0.82, 0.81, 0.82, 0.82, 0.83, 0.82, 0.82, 0.83, 0.82, 0.83, 0.82, 0.82, 0.81, 0.81, 0.82, 0.81, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.83, 0.82, 0.82, 0.82, 0.82, 0.82, 0.81, 0.81, 0.82, 0.82, 0.82, 0.82, 0.81, 0.82, 0.82, 0.82, 0.82, 0.83, 0.83, 0.81, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82, 0.82]
# Optimal number of trees: 7

# %%
plt.plot(num_trees,scores_forest)
plt.xlabel('Number of trees')
plt.ylabel('R2 Score')
plt.title('Random Forest Training')
# Out:
# Text(0.5, 1.0, 'Random Forest Training')

# %%
y_pred = best_model_forest.predict(X_validate)
print("MSE:" + str(mean_squared_error(y_validate,y_pred)))
print("MAE:" + str(mean_absolute_error(y_validate,y_pred)))
print("R2:" + str(r2_score(y_validate,y_pred)))
# Out:
# MSE:0.0830848141900293
# MAE:0.18417978967891516
# R2:0.9238007369762211

# %%
kernels = ['linear', 'rbf', 'poly']
regularization = [1, 10, 100, 1000]
scores_svr = np.zeros([4,4])
results = 0
best_score_svr = 0

for k in range(len(kernels)):
    for c in range(len(regularization)):
        
        model_svr = SVR(kernel=kernels[k],C=regularization[c],gamma='scale',epsilon=0.1)
        model_svr.fit(X_train, y_train.ravel())
        results = model_svr.score(X_test,y_test)
        scores_svr[k,c] = (round(results,2))
        
        if results > best_score_svr:
            best_score_svr = results
            best_kernel = kernels[k]
            best_regularization = regularization[c]
            best_model_svr = model_svr


print("R2:",scores_svr.reshape(1,-1))
print("Optimal kernel:",best_kernel)
print("Optimal regularization:",best_regularization)
# Out:
# R2: [[0.75 0.75 0.75 0.75 0.82 0.83 0.81 0.73 0.73 0.79 0.82 0.82 0.   0.
#   0.   0.  ]]
# Optimal kernel: rbf
# Optimal regularization: 10

# %%
for k in np.arange(len(kernels)):
    plt.plot(regularization,scores_svr[k,:],label=kernels[k])
plt.title('SVR Training')
plt.legend(loc='upper left')
plt.xlabel('regularization')
plt.ylabel('R2 score')
# Out:
# Text(0, 0.5, 'R2 score')

# %%
y_pred = best_model_svr.predict(X_validate)
print("MSE:" + str(mean_squared_error(y_validate,y_pred)))
print("MAE:" + str(mean_absolute_error(y_validate,y_pred)))
print("R2:" + str(r2_score(y_validate,y_pred)))
# Out:
# MSE:0.05493764706597423
# MAE:0.14565152856630095
# R2:0.9496152424543778

# %%
max_depth = range(1,100)
scores_tree = []
results = 0
best_score_tree = 0

for md in max_depth:

    model_tree = DecisionTreeRegressor(criterion='mae',max_depth=md,random_state=0)
    model_tree.fit(X_train, y_train)
    results = model_tree.score(X_test,y_test)
    scores_tree.append(round(results,2))
    
    if results > best_score_tree:
        best_score_tree = results
        best_md = md
        best_model_tree = model_tree
        
print("R2:",scores_tree)
print("Optimal tree depth:",best_md)
# Out:
# R2: [0.66, 0.79, 0.8, 0.82, 0.74, 0.74, 0.74, 0.65, 0.63, 0.6, 0.57, 0.54, 0.54, 0.53, 0.56, 0.53, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54, 0.54]
# Optimal tree depth: 4

# %%
plt.plot(max_depth,scores_tree)
plt.xlabel('Max depth of tree')
plt.ylabel('R2 Score')
plt.title('Decision Tree Training')
# Out:
# Text(0.5, 1.0, 'Decision Tree Training')

# %%
y_pred = best_model_tree.predict(X_validate)
print("MSE:" + str(mean_squared_error(y_validate,y_pred)))
print("MAE:" + str(mean_absolute_error(y_validate,y_pred)))
print("R2:" + str(r2_score(y_validate,y_pred)))
# Out:
# MSE:0.052074009355723525
# MAE:0.10866695858391938
# R2:0.9522415597328774
