# %%
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix

# %%
#Read in dataset
df = pd.read_csv('datasets/dataset_31_credit-g.csv')
df.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0            '<0'         6  'critical/other existing credit'
# 1      '0<=X<200'        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3            '<0'        42                   'existing paid'
# 4            '<0'        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'      '>=7'
# 1             radio/tv           5951              '<100'   '1<=X<4'
# 2            education           2096              '<100'   '4<=X<7'
# 3  furniture/equipment           7882              '<100'   '4<=X<7'
# 4            'new car'           4870              '<100'   '1<=X<4'
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
#Check for null values
np.where(pd.isnull(df))
df.dropna()
# Out:
#     checking_status  duration                    credit_history  \
# 0              '<0'         6  'critical/other existing credit'
# 1        '0<=X<200'        48                   'existing paid'
# 2     'no checking'        12  'critical/other existing credit'
# 3              '<0'        42                   'existing paid'
# 4              '<0'        24              'delayed previously'
# ..              ...       ...                               ...
# 995   'no checking'        12                   'existing paid'
# 996            '<0'        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998            '<0'        45                   'existing paid'
# 999      '0<=X<200'        45  'critical/other existing credit'
#
#                  purpose  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'       '>=7'
# ...

# %%
#Convert class column to integer
df['class'] = preprocessing.LabelEncoder().fit_transform(df["class"])
df.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0            '<0'         6  'critical/other existing credit'
# 1      '0<=X<200'        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3            '<0'        42                   'existing paid'
# 4            '<0'        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'      '>=7'
# 1             radio/tv           5951              '<100'   '1<=X<4'
# 2            education           2096              '<100'   '4<=X<7'
# 3  furniture/equipment           7882              '<100'   '4<=X<7'
# 4            'new car'           4870              '<100'   '1<=X<4'
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
#Plot correlation heatmap
corr = df.corr()
plt.figure(figsize=(8,8))
sns.heatmap(corr,cmap="coolwarm",annot=True)
# Out:
# <AxesSubplot:>

# %%
#Create pair plots
sns.pairplot(df,hue='class')

# %%
#Select columns (nominal = numeric, categorical = non-numeric)
nominal = df[["credit_amount","age","existing_credits","num_dependents"]]
categorical = df[["credit_history","savings_status","housing","job"]]

# %%
#Preprocessing - Basically run OneHotEncoder(sparse=True)
categorical = pd.get_dummies(categorical)
categorical
# Out:
#      credit_history_'all paid'  \
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ..                         ...
# 995                          0
# 996                          0
# 997                          0
# 998                          0
# 999                          0
#
#      credit_history_'critical/other existing credit'  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
# ..                                               ...
# 995                                                0
# 996                                                0
# 997                                                0
# ...

# %%
#Define variables for classifcation
y = df["class"].values

x_columns = len(credit.columns)
X = credit.iloc[:,0:x_columns].values

# %%
#Define training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 0)

# %%
#Split testing set into test and validation sets
X_validate, X_test, y_validate, y_test = train_test_split(X_test,y_test,test_size=0.5,random_state=0)

# %%
#Check variable lengths for each set
print(len(X_train),len(X_test),len(X_validate))
# Out:
# 800 100 100

# %%
#Define a KNN with 3 clusters to start with
knn = KNeighborsClassifier(n_neighbors=3).fit(X_train,y_train)
knn.score(X_test,y_test)
# Out:
# 0.64

# %%
#Be a bit more clever and check for optimal number of clusters
scores = []
neighbors = range(1,20)

for n in neighbors:
    knn = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    results = knn.score(X_test,y_test)
    scores.append(results)
    
print(scores)
plt.plot(neighbors,scores)
# Out:
# [0.59, 0.53, 0.64, 0.57, 0.68, 0.67, 0.66, 0.58, 0.65, 0.65, 0.65, 0.65, 0.69, 0.63, 0.67, 0.65, 0.66, 0.66, 0.67]

# %%
#Redefine KNN with number of clusters showing highest score on test set
knn = KNeighborsClassifier(n_neighbors=13).fit(X_train,y_train)

# %%
#Check model result with validation set
result = knn.score(X_validate,y_validate)
print("Accuracy = ",result)
# Out:
# Accuracy =  0.75

# %%
#Print confusion matrix using validation set
predictions = knn.predict(X_validate)
print("Confusion Matrix: \n",confusion_matrix(y_validate,predictions))
# Out:
# Confusion Matrix:
#  [[ 8 21]
#  [ 4 67]]

# %%
#See whether a decision tree will work better
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(criterion="entropy").fit(X_train,y_train)
results = model.score(X_test,y_test)

print("Accuracy = ",results)
# Out:
# Accuracy =  0.65
